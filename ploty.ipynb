// %% [markdown]
// # Examples of plotly-scala with Almond

// %%
import $ivy.`org.plotly-scala::plotly-almond:0.7.1`
import plotly._, plotly.element._, plotly.layout._, plotly.Almond._

// if you want to have the plots available without an internet connection:
// init(offline=true)

// restrict the output height to avoid scrolling in output cells
repl.pprinter() = repl.pprinter().copy(defaultHeight = 3)
// Out:
// import $ivy.$
//
// import plotly._, plotly.element._, plotly.layout._, plotly.Almond._
//
// // if you want to have the plots available without an internet connection:
// // init(offline=true)
//
// // restrict the output height to avoid scrolling in output cells

// %%
import $ivy.`org.vegas-viz::vegas:0.3.11`
// Out:
// Downloading https://repo1.maven.org/maven2/org/vegas-viz/vegas_2.11/0.3.11/vegas_2.11-0.3.11.pom.sha1
// Downloading https://repo1.maven.org/maven2/org/vegas-viz/vegas_2.11/0.3.11/vegas_2.11-0.3.11.pom
// Downloaded https://repo1.maven.org/maven2/org/vegas-viz/vegas_2.11/0.3.11/vegas_2.11-0.3.11.pom.sha1
// Downloaded https://repo1.maven.org/maven2/org/vegas-viz/vegas_2.11/0.3.11/vegas_2.11-0.3.11.pom
// Downloading https://repo1.maven.org/maven2/io/circe/circe-generic_2.11/0.7.0/circe-generic_2.11-0.7.0.pom.sha1
// Downloading https://repo1.maven.org/maven2/io/circe/circe-core_2.11/0.7.0/circe-core_2.11-0.7.0.pom
// Downloading https://repo1.maven.org/maven2/io/circe/circe-core_2.11/0.7.0/circe-core_2.11-0.7.0.pom.sha1
// Downloading https://repo1.maven.org/maven2/io/circe/circe-generic_2.11/0.7.0/circe-generic_2.11-0.7.0.pom
// Downloading https://repo1.maven.org/maven2/org/vegas-viz/vegas-macros_2.11/0.3.11/vegas-macros_2.11-0.3.11.pom.sha1
// Downloading https://repo1.maven.org/maven2/org/vegas-viz/vegas-macros_2.11/0.3.11/vegas-macros_2.11-0.3.11.pom
// Downloaded https://repo1.maven.org/maven2/io/circe/circe-generic_2.11/0.7.0/circe-generic_2.11-0.7.0.pom.sha1
// Downloading https://repo1.maven.org/maven2/io/circe/circe-parser_2.11/0.7.0/circe-parser_2.11-0.7.0.pom
// Downloaded https://repo1.maven.org/maven2/io/circe/circe-core_2.11/0.7.0/circe-core_2.11-0.7.0.pom
// Downloading https://repo1.maven.org/maven2/io/circe/circe-parser_2.11/0.7.0/circe-parser_2.11-0.7.0.pom.sha1
// Downloaded https://repo1.maven.org/maven2/org/vegas-viz/vegas-macros_2.11/0.3.11/vegas-macros_2.11-0.3.11.pom.sha1
// Downloading https://repo1.maven.org/maven2/org/scala-lang/scala-library/2.11.8/scala-library-2.11.8.pom
// Downloaded https://repo1.maven.org/maven2/io/circe/circe-parser_2.11/0.7.0/circe-parser_2.11-0.7.0.pom
// Downloading https://repo1.maven.org/maven2/org/scala-lang/scala-library/2.11.8/scala-library-2.11.8.pom.sha1
// Downloaded https://repo1.maven.org/maven2/org/vegas-viz/vegas-macros_2.11/0.3.11/vegas-macros_2.11-0.3.11.pom
// Downloaded https://repo1.maven.org/maven2/io/circe/circe-core_2.11/0.7.0/circe-core_2.11-0.7.0.pom.sha1
// Downloading https://repo1.maven.org/maven2/com/github/julien-truffaut/monocle-macro_2.11/1.1.0/monocle-macro_2.11-1.1.0.pom
// Downloading https://repo1.maven.org/maven2/com/github/julien-truffaut/monocle-macro_2.11/1.1.0/monocle-macro_2.11-1.1.0.pom.sha1
// Downloaded https://repo1.maven.org/maven2/io/circe/circe-generic_2.11/0.7.0/circe-generic_2.11-0.7.0.pom
// Downloaded https://repo1.maven.org/maven2/com/github/julien-truffaut/monocle-macro_2.11/1.1.0/monocle-macro_2.11-1.1.0.pom
// Downloading https://repo1.maven.org/maven2/com/github/julien-truffaut/monocle-core_2.11/1.1.0/monocle-core_2.11-1.1.0.pom
// Downloaded https://repo1.maven.org/maven2/io/circe/circe-parser_2.11/0.7.0/circe-parser_2.11-0.7.0.pom.sha1
// Downloaded https://repo1.maven.org/maven2/org/scala-lang/scala-library/2.11.8/scala-library-2.11.8.pom
// Downloading https://repo1.maven.org/maven2/com/github/julien-truffaut/monocle-core_2.11/1.1.0/monocle-core_2.11-1.1.0.pom.sha1
// Downloaded https://repo1.maven.org/maven2/com/github/julien-truffaut/monocle-core_2.11/1.1.0/monocle-core_2.11-1.1.0.pom
// Downloading https://repo1.maven.org/maven2/org/scalafx/scalafx_2.11/8.0.92-R10/scalafx_2.11-8.0.92-R10.pom
// Downloaded https://repo1.maven.org/maven2/org/scala-lang/scala-library/2.11.8/scala-library-2.11.8.pom.sha1
// Downloading https://repo1.maven.org/maven2/org/scalafx/scalafx_2.11/8.0.92-R10/scalafx_2.11-8.0.92-R10.pom.sha1
// Downloaded https://repo1.maven.org/maven2/com/github/julien-truffaut/monocle-macro_2.11/1.1.0/monocle-macro_2.11-1.1.0.pom.sha1
// Downloading https://repo1.maven.org/maven2/org/webjars/bower/vega-lite/1.2.0/vega-lite-1.2.0.pom.sha1
// Downloading https://repo1.maven.org/maven2/org/webjars/bower/vega-lite/1.2.0/vega-lite-1.2.0.pom
// Downloaded https://repo1.maven.org/maven2/org/scalafx/scalafx_2.11/8.0.92-R10/scalafx_2.11-8.0.92-R10.pom.sha1
// Downloaded https://repo1.maven.org/maven2/org/webjars/bower/vega-lite/1.2.0/vega-lite-1.2.0.pom.sha1
// Downloaded https://repo1.maven.org/maven2/org/scalafx/scalafx_2.11/8.0.92-R10/scalafx_2.11-8.0.92-R10.pom
// Downloaded https://repo1.maven.org/maven2/com/github/julien-truffaut/monocle-core_2.11/1.1.0/monocle-core_2.11-1.1.0.pom.sha1
// Downloaded https://repo1.maven.org/maven2/org/webjars/bower/vega-lite/1.2.0/vega-lite-1.2.0.pom
// Downloading https://repo1.maven.org/maven2/org/scala-lang/scala-reflect/2.11.8/scala-reflect-2.11.8.pom
// Downloading https://repo1.maven.org/maven2/org/scala-lang/scala-reflect/2.11.8/scala-reflect-2.11.8.pom.sha1
// Downloading https://repo1.maven.org/maven2/com/chuusai/shapeless_2.11/2.3.2/shapeless_2.11-2.3.2.pom.sha1
// Downloading https://repo1.maven.org/maven2/org/scalaz/scalaz-core_2.11/7.1.1/scalaz-core_2.11-7.1.1.pom
// Downloading https://repo1.maven.org/maven2/org/scalaz/scalaz-core_2.11/7.1.1/scalaz-core_2.11-7.1.1.pom.sha1
// Downloading https://repo1.maven.org/maven2/com/chuusai/shapeless_2.11/2.3.2/shapeless_2.11-2.3.2.pom
// Downloaded https://repo1.maven.org/maven2/org/scala-lang/scala-reflect/2.11.8/scala-reflect-2.11.8.pom.sha1
// Downloaded https://repo1.maven.org/maven2/com/chuusai/shapeless_2.11/2.3.2/shapeless_2.11-2.3.2.pom.sha1
// Downloaded https://repo1.maven.org/maven2/org/scala-lang/scala-reflect/2.11.8/scala-reflect-2.11.8.pom
// Downloading https://repo1.maven.org/maven2/org/typelevel/cats-core_2.11/0.9.0/cats-core_2.11-0.9.0.pom
// Downloading https://repo1.maven.org/maven2/io/circe/circe-jawn_2.11/0.7.0/circe-jawn_2.11-0.7.0.pom.sha1
// Downloaded https://repo1.maven.org/maven2/org/scalaz/scalaz-core_2.11/7.1.1/scalaz-core_2.11-7.1.1.pom
// Downloading https://repo1.maven.org/maven2/org/typelevel/cats-core_2.11/0.9.0/cats-core_2.11-0.9.0.pom.sha1
// Downloading https://repo1.maven.org/maven2/io/circe/circe-jawn_2.11/0.7.0/circe-jawn_2.11-0.7.0.pom
// Downloaded https://repo1.maven.org/maven2/com/chuusai/shapeless_2.11/2.3.2/shapeless_2.11-2.3.2.pom
// Downloading https://repo1.maven.org/maven2/org/webjars/bower/vega/maven-metadata.xml
// Downloaded https://repo1.maven.org/maven2/org/scalaz/scalaz-core_2.11/7.1.1/scalaz-core_2.11-7.1.1.pom.sha1
// Downloading https://repo1.maven.org/maven2/org/webjars/bower/vega/maven-metadata.xml.sha1
// Downloaded https://repo1.maven.org/maven2/io/circe/circe-jawn_2.11/0.7.0/circe-jawn_2.11-0.7.0.pom.sha1
// Downloaded https://repo1.maven.org/maven2/org/typelevel/cats-core_2.11/0.9.0/cats-core_2.11-0.9.0.pom
// Downloading https://repo1.maven.org/maven2/io/circe/circe-numbers_2.11/0.7.0/circe-numbers_2.11-0.7.0.pom
// Downloading https://repo1.maven.org/maven2/io/circe/circe-numbers_2.11/0.7.0/circe-numbers_2.11-0.7.0.pom.sha1
// Downloaded https://repo1.maven.org/maven2/io/circe/circe-jawn_2.11/0.7.0/circe-jawn_2.11-0.7.0.pom
// Downloaded https://repo1.maven.org/maven2/org/typelevel/cats-core_2.11/0.9.0/cats-core_2.11-0.9.0.pom.sha1
// Downloaded https://repo1.maven.org/maven2/org/webjars/bower/vega/maven-metadata.xml
// Downloaded https://repo1.maven.org/maven2/org/webjars/bower/vega/maven-metadata.xml.sha1
// Downloaded https://repo1.maven.org/maven2/io/circe/circe-numbers_2.11/0.7.0/circe-numbers_2.11-0.7.0.pom
// Downloaded https://repo1.maven.org/maven2/io/circe/circe-numbers_2.11/0.7.0/circe-numbers_2.11-0.7.0.pom.sha1
// Downloading https://repo1.maven.org/maven2/org/webjars/bower/vega/3.0.0-rc4/vega-3.0.0-rc4.pom
// Downloading https://repo1.maven.org/maven2/org/webjars/bower/vega/3.0.0-rc4/vega-3.0.0-rc4.pom.sha1
// Downloaded https://repo1.maven.org/maven2/org/webjars/bower/vega/3.0.0-rc4/vega-3.0.0-rc4.pom.sha1
// Downloaded https://repo1.maven.org/maven2/org/webjars/bower/vega/3.0.0-rc4/vega-3.0.0-rc4.pom
// Downloading https://repo1.maven.org/maven2/org/scala-lang/modules/scala-xml_2.11/1.0.2/scala-xml_2.11-1.0.2.pom
// Downloading https://repo1.maven.org/maven2/org/typelevel/cats-kernel_2.11/0.9.0/cats-kernel_2.11-0.9.0.pom.sha1
// Downloading https://repo1.maven.org/maven2/org/typelevel/machinist_2.11/0.6.1/machinist_2.11-0.6.1.pom.sha1
// Downloading https://repo1.maven.org/maven2/org/typelevel/machinist_2.11/0.6.1/machinist_2.11-0.6.1.pom
// Downloading https://repo1.maven.org/maven2/org/typelevel/cats-kernel_2.11/0.9.0/cats-kernel_2.11-0.9.0.pom
// Downloaded https://repo1.maven.org/maven2/org/scala-lang/modules/scala-xml_2.11/1.0.2/scala-xml_2.11-1.0.2.pom
// Downloading https://repo1.maven.org/maven2/org/scala-lang/modules/scala-parser-combinators_2.11/1.0.2/scala-parser-combinators_2.11-1.0.2.pom
// Downloading https://repo1.maven.org/maven2/org/scala-lang/modules/scala-xml_2.11/1.0.2/scala-xml_2.11-1.0.2.pom.sha1
// Downloaded https://repo1.maven.org/maven2/org/typelevel/machinist_2.11/0.6.1/machinist_2.11-0.6.1.pom.sha1
// Downloading https://repo1.maven.org/maven2/org/scala-lang/modules/scala-parser-combinators_2.11/1.0.2/scala-parser-combinators_2.11-1.0.2.pom.sha1
// Downloaded https://repo1.maven.org/maven2/org/typelevel/cats-kernel_2.11/0.9.0/cats-kernel_2.11-0.9.0.pom.sha1
// Downloading https://repo1.maven.org/maven2/com/github/mpilquist/simulacrum_2.11/0.10.0/simulacrum_2.11-0.10.0.pom
// Downloaded https://repo1.maven.org/maven2/org/scala-lang/modules/scala-xml_2.11/1.0.2/scala-xml_2.11-1.0.2.pom.sha1
// Downloading https://repo1.maven.org/maven2/com/github/mpilquist/simulacrum_2.11/0.10.0/simulacrum_2.11-0.10.0.pom.sha1
// Downloaded https://repo1.maven.org/maven2/org/scala-lang/modules/scala-parser-combinators_2.11/1.0.2/scala-parser-combinators_2.11-1.0.2.pom.sha1
// Downloaded https://repo1.maven.org/maven2/org/typelevel/cats-kernel_2.11/0.9.0/cats-kernel_2.11-0.9.0.pom
// Downloaded https://repo1.maven.org/maven2/org/scala-lang/modules/scala-parser-combinators_2.11/1.0.2/scala-parser-combinators_2.11-1.0.2.pom
// Downloading https://repo1.maven.org/maven2/org/spire-math/jawn-parser_2.11/0.10.4/jawn-parser_2.11-0.10.4.pom.sha1
// Downloading https://repo1.maven.org/maven2/org/spire-math/jawn-parser_2.11/0.10.4/jawn-parser_2.11-0.10.4.pom
// Downloaded https://repo1.maven.org/maven2/com/github/mpilquist/simulacrum_2.11/0.10.0/simulacrum_2.11-0.10.0.pom
// Downloaded https://repo1.maven.org/maven2/org/spire-math/jawn-parser_2.11/0.10.4/jawn-parser_2.11-0.10.4.pom.sha1
// Downloaded https://repo1.maven.org/maven2/org/typelevel/machinist_2.11/0.6.1/machinist_2.11-0.6.1.pom
// Downloading https://repo1.maven.org/maven2/org/typelevel/cats-macros_2.11/0.9.0/cats-macros_2.11-0.9.0.pom.sha1
// Downloaded https://repo1.maven.org/maven2/com/github/mpilquist/simulacrum_2.11/0.10.0/simulacrum_2.11-0.10.0.pom.sha1
// Downloading https://repo1.maven.org/maven2/org/typelevel/cats-macros_2.11/0.9.0/cats-macros_2.11-0.9.0.pom
// Downloaded https://repo1.maven.org/maven2/org/spire-math/jawn-parser_2.11/0.10.4/jawn-parser_2.11-0.10.4.pom
// Downloaded https://repo1.maven.org/maven2/org/typelevel/cats-macros_2.11/0.9.0/cats-macros_2.11-0.9.0.pom.sha1
// Downloaded https://repo1.maven.org/maven2/org/typelevel/cats-macros_2.11/0.9.0/cats-macros_2.11-0.9.0.pom
// Downloading https://repo1.maven.org/maven2/com/chuusai/shapeless_2.11/2.3.2/shapeless_2.11-2.3.2.jar
// Downloading https://repo1.maven.org/maven2/com/chuusai/shapeless_2.11/2.3.2/shapeless_2.11-2.3.2.jar.sha1
// Downloading https://repo1.maven.org/maven2/org/typelevel/cats-core_2.11/0.9.0/cats-core_2.11-0.9.0.jar
// Downloading https://repo1.maven.org/maven2/org/typelevel/cats-core_2.11/0.9.0/cats-core_2.11-0.9.0.jar.sha1
// Downloading https://repo1.maven.org/maven2/org/typelevel/cats-macros_2.11/0.9.0/cats-macros_2.11-0.9.0.jar
// Downloading https://repo1.maven.org/maven2/org/typelevel/cats-macros_2.11/0.9.0/cats-macros_2.11-0.9.0.jar.sha1
// Downloaded https://repo1.maven.org/maven2/com/chuusai/shapeless_2.11/2.3.2/shapeless_2.11-2.3.2.jar.sha1
// Downloading https://repo1.maven.org/maven2/org/vegas-viz/vegas_2.11/0.3.11/vegas_2.11-0.3.11.jar
// Downloaded https://repo1.maven.org/maven2/org/typelevel/cats-core_2.11/0.9.0/cats-core_2.11-0.9.0.jar.sha1
// Downloading https://repo1.maven.org/maven2/org/vegas-viz/vegas_2.11/0.3.11/vegas_2.11-0.3.11.jar.sha1
// Downloaded https://repo1.maven.org/maven2/org/typelevel/cats-macros_2.11/0.9.0/cats-macros_2.11-0.9.0.jar.sha1
// Downloaded https://repo1.maven.org/maven2/org/typelevel/cats-macros_2.11/0.9.0/cats-macros_2.11-0.9.0.jar
// Downloading https://repo1.maven.org/maven2/com/github/mpilquist/simulacrum_2.11/0.10.0/simulacrum_2.11-0.10.0.jar.sha1
// Downloading https://repo1.maven.org/maven2/com/github/mpilquist/simulacrum_2.11/0.10.0/simulacrum_2.11-0.10.0.jar
// Downloaded https://repo1.maven.org/maven2/com/github/mpilquist/simulacrum_2.11/0.10.0/simulacrum_2.11-0.10.0.jar.sha1
// Downloading https://repo1.maven.org/maven2/com/github/julien-truffaut/monocle-macro_2.11/1.1.0/monocle-macro_2.11-1.1.0.jar
// Downloaded https://repo1.maven.org/maven2/org/vegas-viz/vegas_2.11/0.3.11/vegas_2.11-0.3.11.jar.sha1
// Downloading https://repo1.maven.org/maven2/com/github/julien-truffaut/monocle-macro_2.11/1.1.0/monocle-macro_2.11-1.1.0.jar.sha1
// Downloaded https://repo1.maven.org/maven2/com/github/julien-truffaut/monocle-macro_2.11/1.1.0/monocle-macro_2.11-1.1.0.jar.sha1
// Downloading https://repo1.maven.org/maven2/org/scalafx/scalafx_2.11/8.0.92-R10/scalafx_2.11-8.0.92-R10.jar
// Downloaded https://repo1.maven.org/maven2/com/github/julien-truffaut/monocle-macro_2.11/1.1.0/monocle-macro_2.11-1.1.0.jar
// Downloading https://repo1.maven.org/maven2/org/scalaz/scalaz-core_2.11/7.1.1/scalaz-core_2.11-7.1.1.jar
// Downloaded https://repo1.maven.org/maven2/com/github/mpilquist/simulacrum_2.11/0.10.0/simulacrum_2.11-0.10.0.jar
// Downloading https://repo1.maven.org/maven2/org/scalafx/scalafx_2.11/8.0.92-R10/scalafx_2.11-8.0.92-R10.jar.sha1
// Downloaded https://repo1.maven.org/maven2/org/scalafx/scalafx_2.11/8.0.92-R10/scalafx_2.11-8.0.92-R10.jar.sha1
// Downloading https://repo1.maven.org/maven2/org/scalaz/scalaz-core_2.11/7.1.1/scalaz-core_2.11-7.1.1.jar.sha1
// Downloaded https://repo1.maven.org/maven2/org/scalaz/scalaz-core_2.11/7.1.1/scalaz-core_2.11-7.1.1.jar.sha1
// Downloading https://repo1.maven.org/maven2/org/vegas-viz/vegas-macros_2.11/0.3.11/vegas-macros_2.11-0.3.11.jar
// Downloaded https://repo1.maven.org/maven2/org/vegas-viz/vegas-macros_2.11/0.3.11/vegas-macros_2.11-0.3.11.jar
// Downloading https://repo1.maven.org/maven2/org/vegas-viz/vegas-macros_2.11/0.3.11/vegas-macros_2.11-0.3.11.jar.sha1
// Downloaded https://repo1.maven.org/maven2/org/vegas-viz/vegas-macros_2.11/0.3.11/vegas-macros_2.11-0.3.11.jar.sha1
// Downloading https://repo1.maven.org/maven2/io/circe/circe-parser_2.11/0.7.0/circe-parser_2.11-0.7.0.jar
// Downloaded https://repo1.maven.org/maven2/io/circe/circe-parser_2.11/0.7.0/circe-parser_2.11-0.7.0.jar
// Downloading https://repo1.maven.org/maven2/io/circe/circe-parser_2.11/0.7.0/circe-parser_2.11-0.7.0.jar.sha1
// Downloaded https://repo1.maven.org/maven2/io/circe/circe-parser_2.11/0.7.0/circe-parser_2.11-0.7.0.jar.sha1
// Downloading https://repo1.maven.org/maven2/org/typelevel/cats-kernel_2.11/0.9.0/cats-kernel_2.11-0.9.0.jar
// Downloaded https://repo1.maven.org/maven2/org/scalafx/scalafx_2.11/8.0.92-R10/scalafx_2.11-8.0.92-R10.jar
// Downloading https://repo1.maven.org/maven2/org/typelevel/cats-kernel_2.11/0.9.0/cats-kernel_2.11-0.9.0.jar.sha1
// Downloaded https://repo1.maven.org/maven2/org/typelevel/cats-kernel_2.11/0.9.0/cats-kernel_2.11-0.9.0.jar.sha1
// Downloading https://repo1.maven.org/maven2/org/scala-lang/scala-reflect/2.11.8/scala-reflect-2.11.8.jar
// Downloaded https://repo1.maven.org/maven2/org/vegas-viz/vegas_2.11/0.3.11/vegas_2.11-0.3.11.jar
// Downloading https://repo1.maven.org/maven2/org/scala-lang/scala-reflect/2.11.8/scala-reflect-2.11.8.jar.sha1
// Downloaded https://repo1.maven.org/maven2/org/scala-lang/scala-reflect/2.11.8/scala-reflect-2.11.8.jar.sha1
// Downloaded https://repo1.maven.org/maven2/org/typelevel/cats-core_2.11/0.9.0/cats-core_2.11-0.9.0.jar
// Downloading https://repo1.maven.org/maven2/org/typelevel/machinist_2.11/0.6.1/machinist_2.11-0.6.1.jar
// Downloaded https://repo1.maven.org/maven2/com/chuusai/shapeless_2.11/2.3.2/shapeless_2.11-2.3.2.jar
// Downloading https://repo1.maven.org/maven2/org/webjars/bower/vega-lite/1.2.0/vega-lite-1.2.0.jar
// Downloading https://repo1.maven.org/maven2/org/typelevel/machinist_2.11/0.6.1/machinist_2.11-0.6.1.jar.sha1
// Downloaded https://repo1.maven.org/maven2/org/typelevel/machinist_2.11/0.6.1/machinist_2.11-0.6.1.jar
// Downloading https://repo1.maven.org/maven2/org/webjars/bower/vega-lite/1.2.0/vega-lite-1.2.0.jar.sha1
// Downloaded https://repo1.maven.org/maven2/org/typelevel/machinist_2.11/0.6.1/machinist_2.11-0.6.1.jar.sha1
// Downloading https://repo1.maven.org/maven2/io/circe/circe-jawn_2.11/0.7.0/circe-jawn_2.11-0.7.0.jar
// Downloaded https://repo1.maven.org/maven2/org/webjars/bower/vega-lite/1.2.0/vega-lite-1.2.0.jar.sha1
// Downloading https://repo1.maven.org/maven2/io/circe/circe-jawn_2.11/0.7.0/circe-jawn_2.11-0.7.0.jar.sha1
// Downloaded https://repo1.maven.org/maven2/io/circe/circe-jawn_2.11/0.7.0/circe-jawn_2.11-0.7.0.jar
// Downloading https://repo1.maven.org/maven2/org/scala-lang/scala-library/2.11.8/scala-library-2.11.8.jar
// Downloaded https://repo1.maven.org/maven2/io/circe/circe-jawn_2.11/0.7.0/circe-jawn_2.11-0.7.0.jar.sha1
// Downloading https://repo1.maven.org/maven2/org/scala-lang/scala-library/2.11.8/scala-library-2.11.8.jar.sha1
// Downloaded https://repo1.maven.org/maven2/org/scala-lang/scala-library/2.11.8/scala-library-2.11.8.jar.sha1
// Downloading https://repo1.maven.org/maven2/org/webjars/bower/vega/3.0.0-rc4/vega-3.0.0-rc4.jar.sha1
// Downloaded https://repo1.maven.org/maven2/org/webjars/bower/vega-lite/1.2.0/vega-lite-1.2.0.jar
// Downloading https://repo1.maven.org/maven2/org/webjars/bower/vega/3.0.0-rc4/vega-3.0.0-rc4.jar
// Downloaded https://repo1.maven.org/maven2/org/webjars/bower/vega/3.0.0-rc4/vega-3.0.0-rc4.jar.sha1
// Downloading https://repo1.maven.org/maven2/io/circe/circe-core_2.11/0.7.0/circe-core_2.11-0.7.0.jar
// Downloaded https://repo1.maven.org/maven2/org/typelevel/cats-kernel_2.11/0.9.0/cats-kernel_2.11-0.9.0.jar
// Downloading https://repo1.maven.org/maven2/io/circe/circe-generic_2.11/0.7.0/circe-generic_2.11-0.7.0.jar
// Downloaded https://repo1.maven.org/maven2/io/circe/circe-generic_2.11/0.7.0/circe-generic_2.11-0.7.0.jar
// Downloading https://repo1.maven.org/maven2/io/circe/circe-core_2.11/0.7.0/circe-core_2.11-0.7.0.jar.sha1
// Downloaded https://repo1.maven.org/maven2/io/circe/circe-core_2.11/0.7.0/circe-core_2.11-0.7.0.jar.sha1
// Downloading https://repo1.maven.org/maven2/com/chuusai/shapeless_2.11/2.3.2/shapeless_2.11-2.3.2-sources.jar
// Downloaded https://repo1.maven.org/maven2/io/circe/circe-core_2.11/0.7.0/circe-core_2.11-0.7.0.jar
// Downloading https://repo1.maven.org/maven2/io/circe/circe-generic_2.11/0.7.0/circe-generic_2.11-0.7.0.jar.sha1
// Downloaded https://repo1.maven.org/maven2/io/circe/circe-generic_2.11/0.7.0/circe-generic_2.11-0.7.0.jar.sha1
// Downloading https://repo1.maven.org/maven2/com/chuusai/shapeless_2.11/2.3.2/shapeless_2.11-2.3.2-sources.jar.sha1
// Downloaded https://repo1.maven.org/maven2/com/chuusai/shapeless_2.11/2.3.2/shapeless_2.11-2.3.2-sources.jar
// Downloading https://repo1.maven.org/maven2/org/typelevel/cats-macros_2.11/0.9.0/cats-macros_2.11-0.9.0-sources.jar
// Downloaded https://repo1.maven.org/maven2/com/chuusai/shapeless_2.11/2.3.2/shapeless_2.11-2.3.2-sources.jar.sha1
// Downloading https://repo1.maven.org/maven2/org/scalafx/scalafx_2.11/8.0.92-R10/scalafx_2.11-8.0.92-R10-sources.jar
// Downloaded https://repo1.maven.org/maven2/org/typelevel/cats-macros_2.11/0.9.0/cats-macros_2.11-0.9.0-sources.jar
// Downloading https://repo1.maven.org/maven2/org/typelevel/cats-macros_2.11/0.9.0/cats-macros_2.11-0.9.0-sources.jar.sha1
// Downloaded https://repo1.maven.org/maven2/org/typelevel/cats-macros_2.11/0.9.0/cats-macros_2.11-0.9.0-sources.jar.sha1
// Downloading https://repo1.maven.org/maven2/org/scalafx/scalafx_2.11/8.0.92-R10/scalafx_2.11-8.0.92-R10-sources.jar.sha1
// Downloaded https://repo1.maven.org/maven2/org/scala-lang/scala-reflect/2.11.8/scala-reflect-2.11.8.jar
// Downloaded https://repo1.maven.org/maven2/org/scalafx/scalafx_2.11/8.0.92-R10/scalafx_2.11-8.0.92-R10-sources.jar.sha1
// Downloading https://repo1.maven.org/maven2/org/spire-math/jawn-parser_2.11/0.10.4/jawn-parser_2.11-0.10.4-sources.jar
// Downloading https://repo1.maven.org/maven2/com/github/julien-truffaut/monocle-core_2.11/1.1.0/monocle-core_2.11-1.1.0-sources.jar.sha1
// Downloaded https://repo1.maven.org/maven2/com/github/julien-truffaut/monocle-core_2.11/1.1.0/monocle-core_2.11-1.1.0-sources.jar.sha1
// Downloading https://repo1.maven.org/maven2/com/github/julien-truffaut/monocle-core_2.11/1.1.0/monocle-core_2.11-1.1.0-sources.jar
// Downloaded https://repo1.maven.org/maven2/org/spire-math/jawn-parser_2.11/0.10.4/jawn-parser_2.11-0.10.4-sources.jar
// Downloading https://repo1.maven.org/maven2/org/spire-math/jawn-parser_2.11/0.10.4/jawn-parser_2.11-0.10.4-sources.jar.sha1
// Downloaded https://repo1.maven.org/maven2/org/spire-math/jawn-parser_2.11/0.10.4/jawn-parser_2.11-0.10.4-sources.jar.sha1
// Downloaded https://repo1.maven.org/maven2/org/scalafx/scalafx_2.11/8.0.92-R10/scalafx_2.11-8.0.92-R10-sources.jar
// Downloading https://repo1.maven.org/maven2/com/github/julien-truffaut/monocle-macro_2.11/1.1.0/monocle-macro_2.11-1.1.0-sources.jar
// Downloaded https://repo1.maven.org/maven2/com/github/julien-truffaut/monocle-core_2.11/1.1.0/monocle-core_2.11-1.1.0-sources.jar
// Downloading https://repo1.maven.org/maven2/com/github/mpilquist/simulacrum_2.11/0.10.0/simulacrum_2.11-0.10.0-sources.jar
// Downloading https://repo1.maven.org/maven2/com/github/julien-truffaut/monocle-macro_2.11/1.1.0/monocle-macro_2.11-1.1.0-sources.jar.sha1
// Downloaded https://repo1.maven.org/maven2/com/github/julien-truffaut/monocle-macro_2.11/1.1.0/monocle-macro_2.11-1.1.0-sources.jar.sha1
// Downloading https://repo1.maven.org/maven2/org/vegas-viz/vegas_2.11/0.3.11/vegas_2.11-0.3.11-sources.jar
// Downloaded https://repo1.maven.org/maven2/com/github/julien-truffaut/monocle-macro_2.11/1.1.0/monocle-macro_2.11-1.1.0-sources.jar
// Downloaded https://repo1.maven.org/maven2/com/github/mpilquist/simulacrum_2.11/0.10.0/simulacrum_2.11-0.10.0-sources.jar
// Downloading https://repo1.maven.org/maven2/org/vegas-viz/vegas_2.11/0.3.11/vegas_2.11-0.3.11-sources.jar.sha1
// Downloading https://repo1.maven.org/maven2/com/github/mpilquist/simulacrum_2.11/0.10.0/simulacrum_2.11-0.10.0-sources.jar.sha1
// Downloaded https://repo1.maven.org/maven2/org/vegas-viz/vegas_2.11/0.3.11/vegas_2.11-0.3.11-sources.jar.sha1
// Downloading https://repo1.maven.org/maven2/org/vegas-viz/vegas-macros_2.11/0.3.11/vegas-macros_2.11-0.3.11-sources.jar
// Downloaded https://repo1.maven.org/maven2/com/github/mpilquist/simulacrum_2.11/0.10.0/simulacrum_2.11-0.10.0-sources.jar.sha1
// Downloading https://repo1.maven.org/maven2/org/vegas-viz/vegas-macros_2.11/0.3.11/vegas-macros_2.11-0.3.11-sources.jar.sha1
// Downloaded https://repo1.maven.org/maven2/org/vegas-viz/vegas_2.11/0.3.11/vegas_2.11-0.3.11-sources.jar
// Downloading https://repo1.maven.org/maven2/io/circe/circe-parser_2.11/0.7.0/circe-parser_2.11-0.7.0-sources.jar.sha1
// Downloaded https://repo1.maven.org/maven2/org/vegas-viz/vegas-macros_2.11/0.3.11/vegas-macros_2.11-0.3.11-sources.jar
// Downloading https://repo1.maven.org/maven2/io/circe/circe-parser_2.11/0.7.0/circe-parser_2.11-0.7.0-sources.jar
// Downloaded https://repo1.maven.org/maven2/io/circe/circe-parser_2.11/0.7.0/circe-parser_2.11-0.7.0-sources.jar.sha1
// Downloading https://repo1.maven.org/maven2/io/circe/circe-numbers_2.11/0.7.0/circe-numbers_2.11-0.7.0.jar
// Downloaded https://repo1.maven.org/maven2/org/vegas-viz/vegas-macros_2.11/0.3.11/vegas-macros_2.11-0.3.11-sources.jar.sha1
// Downloading https://repo1.maven.org/maven2/org/scala-lang/scala-reflect/2.11.8/scala-reflect-2.11.8-sources.jar
// Downloaded https://repo1.maven.org/maven2/io/circe/circe-parser_2.11/0.7.0/circe-parser_2.11-0.7.0-sources.jar
// Downloaded https://repo1.maven.org/maven2/io/circe/circe-numbers_2.11/0.7.0/circe-numbers_2.11-0.7.0.jar
// Downloading https://repo1.maven.org/maven2/org/scala-lang/scala-reflect/2.11.8/scala-reflect-2.11.8-sources.jar.sha1
// Downloading https://repo1.maven.org/maven2/io/circe/circe-numbers_2.11/0.7.0/circe-numbers_2.11-0.7.0.jar.sha1
// Downloaded https://repo1.maven.org/maven2/org/scala-lang/scala-reflect/2.11.8/scala-reflect-2.11.8-sources.jar.sha1
// Downloading https://repo1.maven.org/maven2/org/typelevel/cats-kernel_2.11/0.9.0/cats-kernel_2.11-0.9.0-sources.jar
// Downloaded https://repo1.maven.org/maven2/org/scalaz/scalaz-core_2.11/7.1.1/scalaz-core_2.11-7.1.1.jar
// Downloading https://repo1.maven.org/maven2/io/circe/circe-jawn_2.11/0.7.0/circe-jawn_2.11-0.7.0-sources.jar.sha1
// Downloaded https://repo1.maven.org/maven2/io/circe/circe-numbers_2.11/0.7.0/circe-numbers_2.11-0.7.0.jar.sha1
// Downloading https://repo1.maven.org/maven2/io/circe/circe-jawn_2.11/0.7.0/circe-jawn_2.11-0.7.0-sources.jar
// Downloaded https://repo1.maven.org/maven2/org/scala-lang/scala-library/2.11.8/scala-library-2.11.8.jar
// Downloading https://repo1.maven.org/maven2/org/typelevel/cats-kernel_2.11/0.9.0/cats-kernel_2.11-0.9.0-sources.jar.sha1
// Downloaded https://repo1.maven.org/maven2/io/circe/circe-jawn_2.11/0.7.0/circe-jawn_2.11-0.7.0-sources.jar.sha1
// Downloading https://repo1.maven.org/maven2/org/scala-lang/modules/scala-xml_2.11/1.0.2/scala-xml_2.11-1.0.2.jar
// Downloaded https://repo1.maven.org/maven2/io/circe/circe-jawn_2.11/0.7.0/circe-jawn_2.11-0.7.0-sources.jar
// Downloading https://repo1.maven.org/maven2/org/scala-lang/modules/scala-xml_2.11/1.0.2/scala-xml_2.11-1.0.2.jar.sha1
// Downloaded https://repo1.maven.org/maven2/org/typelevel/cats-kernel_2.11/0.9.0/cats-kernel_2.11-0.9.0-sources.jar
// Downloading https://repo1.maven.org/maven2/org/typelevel/machinist_2.11/0.6.1/machinist_2.11-0.6.1-sources.jar
// Downloaded https://repo1.maven.org/maven2/org/scala-lang/scala-reflect/2.11.8/scala-reflect-2.11.8-sources.jar
// Downloading https://repo1.maven.org/maven2/org/typelevel/machinist_2.11/0.6.1/machinist_2.11-0.6.1-sources.jar.sha1
// Downloaded https://repo1.maven.org/maven2/org/typelevel/cats-kernel_2.11/0.9.0/cats-kernel_2.11-0.9.0-sources.jar.sha1
// Downloading https://repo1.maven.org/maven2/org/webjars/bower/vega-lite/1.2.0/vega-lite-1.2.0-sources.jar
// Downloaded https://repo1.maven.org/maven2/org/typelevel/machinist_2.11/0.6.1/machinist_2.11-0.6.1-sources.jar
// Downloading https://repo1.maven.org/maven2/org/webjars/bower/vega-lite/1.2.0/vega-lite-1.2.0-sources.jar.sha1
// Downloaded https://repo1.maven.org/maven2/org/scala-lang/modules/scala-xml_2.11/1.0.2/scala-xml_2.11-1.0.2.jar.sha1
// Downloading https://repo1.maven.org/maven2/org/scala-lang/scala-library/2.11.8/scala-library-2.11.8-sources.jar
// Downloaded https://repo1.maven.org/maven2/org/typelevel/machinist_2.11/0.6.1/machinist_2.11-0.6.1-sources.jar.sha1
// Downloading https://repo1.maven.org/maven2/org/scala-lang/scala-library/2.11.8/scala-library-2.11.8-sources.jar.sha1
// Downloaded https://repo1.maven.org/maven2/org/webjars/bower/vega-lite/1.2.0/vega-lite-1.2.0-sources.jar
// Downloading https://repo1.maven.org/maven2/org/scala-lang/modules/scala-xml_2.11/1.0.2/scala-xml_2.11-1.0.2-sources.jar
// Downloaded https://repo1.maven.org/maven2/org/scala-lang/scala-library/2.11.8/scala-library-2.11.8-sources.jar.sha1
// Downloading https://repo1.maven.org/maven2/org/scala-lang/modules/scala-xml_2.11/1.0.2/scala-xml_2.11-1.0.2-sources.jar.sha1
// Downloaded https://repo1.maven.org/maven2/org/webjars/bower/vega-lite/1.2.0/vega-lite-1.2.0-sources.jar.sha1
// Downloading https://repo1.maven.org/maven2/io/circe/circe-generic_2.11/0.7.0/circe-generic_2.11-0.7.0-sources.jar
// Downloaded https://repo1.maven.org/maven2/org/scala-lang/modules/scala-xml_2.11/1.0.2/scala-xml_2.11-1.0.2.jar
// Downloading https://repo1.maven.org/maven2/io/circe/circe-generic_2.11/0.7.0/circe-generic_2.11-0.7.0-sources.jar.sha1
// Downloaded https://repo1.maven.org/maven2/io/circe/circe-generic_2.11/0.7.0/circe-generic_2.11-0.7.0-sources.jar
// Downloading https://repo1.maven.org/maven2/org/scalaz/scalaz-core_2.11/7.1.1/scalaz-core_2.11-7.1.1-sources.jar
// Downloaded https://repo1.maven.org/maven2/org/scala-lang/modules/scala-xml_2.11/1.0.2/scala-xml_2.11-1.0.2-sources.jar
// Downloading https://repo1.maven.org/maven2/org/scalaz/scalaz-core_2.11/7.1.1/scalaz-core_2.11-7.1.1-sources.jar.sha1
// Downloaded https://repo1.maven.org/maven2/org/scala-lang/modules/scala-xml_2.11/1.0.2/scala-xml_2.11-1.0.2-sources.jar.sha1
// Downloading https://repo1.maven.org/maven2/org/webjars/bower/vega/3.0.0-rc4/vega-3.0.0-rc4-sources.jar.sha1
// Downloaded https://repo1.maven.org/maven2/io/circe/circe-generic_2.11/0.7.0/circe-generic_2.11-0.7.0-sources.jar.sha1
// Downloading https://repo1.maven.org/maven2/org/webjars/bower/vega/3.0.0-rc4/vega-3.0.0-rc4-sources.jar
// Downloaded https://repo1.maven.org/maven2/org/scalaz/scalaz-core_2.11/7.1.1/scalaz-core_2.11-7.1.1-sources.jar.sha1
// Downloading https://repo1.maven.org/maven2/org/scala-lang/modules/scala-parser-combinators_2.11/1.0.2/scala-parser-combinators_2.11-1.0.2.jar
// Downloaded https://repo1.maven.org/maven2/org/scala-lang/scala-library/2.11.8/scala-library-2.11.8-sources.jar
// Downloading https://repo1.maven.org/maven2/org/scala-lang/modules/scala-parser-combinators_2.11/1.0.2/scala-parser-combinators_2.11-1.0.2.jar.sha1
// Downloaded https://repo1.maven.org/maven2/org/scalaz/scalaz-core_2.11/7.1.1/scalaz-core_2.11-7.1.1-sources.jar
// Downloading https://repo1.maven.org/maven2/org/scala-lang/modules/scala-parser-combinators_2.11/1.0.2/scala-parser-combinators_2.11-1.0.2-sources.jar
// Downloaded https://repo1.maven.org/maven2/org/webjars/bower/vega/3.0.0-rc4/vega-3.0.0-rc4-sources.jar.sha1
// Downloading https://repo1.maven.org/maven2/org/scala-lang/modules/scala-parser-combinators_2.11/1.0.2/scala-parser-combinators_2.11-1.0.2-sources.jar.sha1
// Downloaded https://repo1.maven.org/maven2/org/scala-lang/modules/scala-parser-combinators_2.11/1.0.2/scala-parser-combinators_2.11-1.0.2.jar.sha1
// Downloading https://repo1.maven.org/maven2/org/spire-math/jawn-parser_2.11/0.10.4/jawn-parser_2.11-0.10.4.jar
// Downloaded https://repo1.maven.org/maven2/org/webjars/bower/vega/3.0.0-rc4/vega-3.0.0-rc4-sources.jar
// Downloading https://repo1.maven.org/maven2/org/spire-math/jawn-parser_2.11/0.10.4/jawn-parser_2.11-0.10.4.jar.sha1
// Downloaded https://repo1.maven.org/maven2/org/scala-lang/modules/scala-parser-combinators_2.11/1.0.2/scala-parser-combinators_2.11-1.0.2.jar
// Downloading https://repo1.maven.org/maven2/com/github/julien-truffaut/monocle-core_2.11/1.1.0/monocle-core_2.11-1.1.0.jar
// Downloaded https://repo1.maven.org/maven2/org/spire-math/jawn-parser_2.11/0.10.4/jawn-parser_2.11-0.10.4.jar.sha1
// Downloading https://repo1.maven.org/maven2/com/github/julien-truffaut/monocle-core_2.11/1.1.0/monocle-core_2.11-1.1.0.jar.sha1
// Downloaded https://repo1.maven.org/maven2/org/scala-lang/modules/scala-parser-combinators_2.11/1.0.2/scala-parser-combinators_2.11-1.0.2-sources.jar
// Downloaded https://repo1.maven.org/maven2/org/scala-lang/modules/scala-parser-combinators_2.11/1.0.2/scala-parser-combinators_2.11-1.0.2-sources.jar.sha1
// Downloading https://repo1.maven.org/maven2/org/typelevel/cats-core_2.11/0.9.0/cats-core_2.11-0.9.0-sources.jar
// Downloaded https://repo1.maven.org/maven2/org/spire-math/jawn-parser_2.11/0.10.4/jawn-parser_2.11-0.10.4.jar
// Downloading https://repo1.maven.org/maven2/org/typelevel/cats-core_2.11/0.9.0/cats-core_2.11-0.9.0-sources.jar.sha1
// Downloading https://repo1.maven.org/maven2/io/circe/circe-numbers_2.11/0.7.0/circe-numbers_2.11-0.7.0-sources.jar
// Downloaded https://repo1.maven.org/maven2/com/github/julien-truffaut/monocle-core_2.11/1.1.0/monocle-core_2.11-1.1.0.jar.sha1
// Downloading https://repo1.maven.org/maven2/io/circe/circe-numbers_2.11/0.7.0/circe-numbers_2.11-0.7.0-sources.jar.sha1
// Downloaded https://repo1.maven.org/maven2/io/circe/circe-numbers_2.11/0.7.0/circe-numbers_2.11-0.7.0-sources.jar
// Downloading https://repo1.maven.org/maven2/io/circe/circe-core_2.11/0.7.0/circe-core_2.11-0.7.0-sources.jar
// Downloaded https://repo1.maven.org/maven2/org/typelevel/cats-core_2.11/0.9.0/cats-core_2.11-0.9.0-sources.jar.sha1
// Downloading https://repo1.maven.org/maven2/io/circe/circe-core_2.11/0.7.0/circe-core_2.11-0.7.0-sources.jar.sha1
// Downloaded https://repo1.maven.org/maven2/org/typelevel/cats-core_2.11/0.9.0/cats-core_2.11-0.9.0-sources.jar
// Downloaded https://repo1.maven.org/maven2/com/github/julien-truffaut/monocle-core_2.11/1.1.0/monocle-core_2.11-1.1.0.jar
// Downloaded https://repo1.maven.org/maven2/io/circe/circe-core_2.11/0.7.0/circe-core_2.11-0.7.0-sources.jar.sha1
// Downloaded https://repo1.maven.org/maven2/io/circe/circe-numbers_2.11/0.7.0/circe-numbers_2.11-0.7.0-sources.jar.sha1
// Downloaded https://repo1.maven.org/maven2/io/circe/circe-core_2.11/0.7.0/circe-core_2.11-0.7.0-sources.jar
// Downloaded https://repo1.maven.org/maven2/org/webjars/bower/vega/3.0.0-rc4/vega-3.0.0-rc4.jar
// import $ivy.$

// %%
import vegas._
import vegas.data.External._
// Out:
// import vegas._
//
// import vegas.data.External._

// %%
val plot = Vegas("Country Pop").
  withData(
    Seq(
      Map("country" -> "USA", "population" -> 314),
      Map("country" -> "UK", "population" -> 64),
      Map("country" -> "DK", "population" -> 80)
    )
  ).
  encodeX("country", Nom).
  encodeY("population", Quant).
  mark(Bar)
// Out:
// plot: DSL.ExtendedUnitSpecBuilder = ExtendedUnitSpecBuilder(
//   ExtendedUnitSpec(
//     None,
//     None,
//     Bar,
//     Some(
//       Encoding(
//         None,
//         None,
//         Some(
//           PositionChannelDef(
//             None,
//             None,
//             None,
//             Some("country"),
//             Some(Nominal),
//             None,
//             None,
//             None,
//             None,
//             None
//           )
//         ),
//         Some(
//           PositionChannelDef(
//             None,
//             None,
//             None,
//             Some("population"),
//             Some(Quantitative),
//             None,
//             None,
//             None,
//             None,
//             None
//           )
//         ),
//         None,
//         None,
// ...

// %%
plot.show
// Out:
//   <iframe id="frame-vegas-9bb9cde5-c4af-45cf-a014-73400227f3b4" sandbox="allow-scripts allow-same-origin" style="border: none; width: 100%" srcdoc="&lt;html&gt;
//   &lt;head&gt;
//     &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/d3/3.5.17/d3.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega/2.6.3/vega.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega-lite/1.2.0/vega-lite.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://vega.github.io/vega-editor/vendor/vega-embed.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
//   &lt;/head&gt;
//   &lt;body&gt;
//  &lt;div id='vegas-9bb9cde5-c4af-45cf-a014-73400227f3b4'&gt;&lt;/div&gt;
//  &lt;script&gt;
//    var embedSpec = {
//      mode: &quot;vega-lite&quot;,
//      spec: {
//   &quot;mark&quot; : &quot;bar&quot;,
//   &quot;encoding&quot; : {
//     &quot;x&quot; : {
//       &quot;field&quot; : &quot;country&quot;,
//       &quot;type&quot; : &quot;nominal&quot;
//     },
//     &quot;y&quot; : {
//       &quot;field&quot; : &quot;population&quot;,
//       &quot;type&quot; : &quot;quantitative&quot;
//     }
//   },
//   &quot;description&quot; : &quot;Country Pop&quot;,
//   &quot;data&quot; : {
//     &quot;values&quot; : [
//       {
//         &quot;country&quot; : &quot;USA&quot;,
//         &quot;population&quot; : 314
//       },
//       {
//         &quot;country&quot; : &quot;UK&quot;,
//         &quot;population&quot; : 64
//       },
//       {
//         &quot;country&quot; : &quot;DK&quot;,
//         &quot;population&quot; : 80
//       }
//     ]
//   }
// }
//    }
//    vg.embed(&quot;#vegas-9bb9cde5-c4af-45cf-a014-73400227f3b4&quot;, embedSpec, function(error, result) {});
//  &lt;/script&gt;
//
//     &lt;/body&gt;
// &lt;/html&gt;"></iframe>
//   <script>
//     (function() {
//       function resizeIFrame(el, k) {
//         var height = el.contentWindow.document.body.scrollHeight || '400'; // Fallback in case of no scroll height
//         el.style.height = height + 'px';
//         if (k <= 10) { setTimeout(function() { resizeIFrame(el, k+1) }, 1000 + (k * 250)) };
//       }
//       resizeIFrame(document.querySelector('#frame-vegas-9bb9cde5-c4af-45cf-a014-73400227f3b4'), 1);
//     })(); // IIFE
//   </script>

// %%
implicit val render = vegas.render.ShowHTML(publish(_))

// %%
val trace1 = Scatter(
  Seq(1, 2, 3, 4),
  Seq(10, 15, 13, 17)
)

val trace2 = Scatter(
  Seq(1, 2, 3, 4),
  Seq(16, 5, 11, 9)
)

val data = Seq(trace1, trace2)

plot(data)
// Out:
//       <script type="text/javascript">
//         require.config({
//   paths: {
//     d3: 'https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.17/d3.min',
//     plotly: 'https://cdn.plot.ly/plotly-1.12.0.min',
//     jquery: 'https://code.jquery.com/jquery-3.3.1.min'
//   },
//
//   shim: {
//     plotly: {
//       deps: ['d3', 'jquery'],
//       exports: 'plotly'
//     }
//   }
// });
//
//
//         require(['plotly'], function(Plotly) {
//           window.Plotly = Plotly;
//         });
//       </script>
// trace1: Scatter = Scatter(
//   Some(Doubles(List(1.0, 2.0, 3.0, 4.0))),
// ...
// trace2: Scatter = Scatter(
//   Some(Doubles(List(1.0, 2.0, 3.0, 4.0))),
// ...
// data: Seq[Scatter] = List(
//   Scatter(
// ...
// res1_3: String = "plot-1406266631"

// %% [markdown]
// ## Line and Scatter Plot

// %%
val trace1 = Scatter(
  Seq(1, 2, 3, 4),
  Seq(10, 15, 13, 17),
  mode = ScatterMode(ScatterMode.Markers)
)

val trace2 = Scatter(
  Seq(2, 3, 4, 5),
  Seq(16, 5, 11, 9),
  mode = ScatterMode(ScatterMode.Lines)
)

val trace3 = Scatter(
  Seq(1, 2, 3, 4),
  Seq(12, 9, 15, 12),
  mode = ScatterMode(ScatterMode.Lines, ScatterMode.Markers)
)

val data = Seq(trace1, trace2, trace3)

val layout = Layout(
  title = "Line and Scatter Plot"
)

plot(data, layout)
// Out:
// trace1: Scatter = Scatter(
//   Some(Doubles(List(1.0, 2.0, 3.0, 4.0))),
// ...
// trace2: Scatter = Scatter(
//   Some(Doubles(List(2.0, 3.0, 4.0, 5.0))),
// ...
// trace3: Scatter = Scatter(
//   Some(Doubles(List(1.0, 2.0, 3.0, 4.0))),
// ...
// data: Seq[Scatter] = List(
//   Scatter(
// ...
// layout: Layout = Layout(
//   Some("Line and Scatter Plot"),
// ...
// res2_5: String = "plot-1100144389"

// %% [markdown]
// # Scatter Plots
// ## Categorical Dot Plot

// %%
val country = Seq(
  "Switzerland (2011)",
  "Chile (2013)",
  "Japan (2014)",
  "United States (2012)",
  "Slovenia (2014)",
  "Canada (2011)",
  "Poland (2010)",
  "Estonia (2015)",
  "Luxembourg (2013)",
  "Portugal (2011)"
)

val votingPop = Seq(
  40.0, 45.7, 52.0, 53.6, 54.1, 54.2, 54.5, 54.7, 55.1, 56.6
)

val regVoters = Seq(
  49.1, 42.0, 52.7, 84.3, 51.7, 61.1, 55.3, 64.2, 91.1, 58.9
)

val trace1 = Scatter(
  votingPop,
  country,
  mode = ScatterMode(ScatterMode.Markers),
  name = "Percent of estimated voting age population",
  marker = Marker(
    color = Color.RGBA(156, 165, 196, 0.95),
    line = Line(
      color = Color.RGBA(156, 165, 196, 1.0),
      width = 1.0
    ),
    symbol = Symbol.Circle(),
    size = 16
  )
)

val trace2 = Scatter(
  regVoters,
  country,
  mode = ScatterMode(ScatterMode.Markers),
  name = "Percent of estimated registered voters",
  marker = Marker(
    color = Color.RGBA(204, 204, 204, 0.95),
    line = Line(
      color = Color.RGBA(217, 217, 217, 1.0),
      width = 1.0
    ),
    symbol = Symbol.Circle(),
    size = 16
  )
)

val data = Seq(trace1, trace2)

val layout = Layout(
  title = "Votes cast for ten lowest voting age population in OECD countries",
  xaxis = Axis(
    showgrid = false,
    showline = true,
    linecolor = Color.RGB(102, 102, 102),
    titlefont = Font(
      color = Color.RGB(204, 204, 204)
    ),
    tickfont = Font(
      color = Color.RGB(102, 102, 102)
    ),
    autotick = false,
    dtick = 10.0,
    ticks = Ticks.Outside,
    tickcolor = Color.RGB(102, 102, 102)
  ),
  margin = Margin(
    l = 140,
    r = 40,
    b = 50,
    t = 80
  ),
  legend = Legend(
    font = Font(
      size = 10
    ),
    yanchor = Anchor.Middle,
    xanchor = Anchor.Right
  ),
  width = 600,
  height = 400,
  paper_bgcolor = Color.RGB(254, 247, 234),
  plot_bgcolor = Color.RGB(254, 247, 234),
  hovermode = HoverMode.Closest
)

plot(data, layout)
// Out:
// country: Seq[String] = List(
//   "Switzerland (2011)",
// ...
// votingPop: Seq[Double] = List(
//   40.0,
// ...
// regVoters: Seq[Double] = List(
//   49.1,
// ...
// trace1: Scatter = Scatter(
//   Some(
// ...
// trace2: Scatter = Scatter(
//   Some(
// ...
// data: Seq[Scatter] = List(
//   Scatter(
// ...
// layout: Layout = Layout(
//   Some("Votes cast for ten lowest voting age population in OECD countries"),
// ...
// res3_7: String = "plot-1485480897"

// %% [markdown]
// # Bar Charts
// ## Basic Bar Chart

// %%
val data = Seq(
  Bar(
    Seq("giraffes", "orangutans", "monkeys"),
    Seq(20, 14, 23)
  )
)

plot(data)
// Out:
// data: Seq[Bar] = List(
//   Bar(
// ...
// res4_1: String = "plot-1904469197"

// %% [markdown]
// ## Grouped Bar Chart

// %%
val trace1 = Bar(
  Seq("giraffes", "orangutans", "monkeys"),
  Seq(20, 14, 23),
  name = "SF Zoo"
)

val trace2 = Bar(
  Seq("giraffes", "orangutans", "monkeys"),
  Seq(12, 18, 29),
  name = "LA Zoo"
)

val data = Seq(trace1, trace2)

val layout = Layout( 
  barmode = BarMode.Group
)

plot(data, layout)
// Out:
// trace1: Bar = Bar(
//   Strings(List("giraffes", "orangutans", "monkeys")),
// ...
// trace2: Bar = Bar(
//   Strings(List("giraffes", "orangutans", "monkeys")),
// ...
// data: Seq[Bar] = List(
//   Bar(
// ...
// layout: Layout = Layout(
//   None,
// ...
// res5_4: String = "plot-1514217005"

// %% [markdown]
// ## Bar Chart with Direct Labels

// %%
val xValue = Seq("Product A", "Product B", "Product C")

val yValue = Seq(20, 14, 23)

val trace1 = Bar(
  xValue,
  yValue,
  text = Seq("27% market share", "24% market share", "19% market share"),
  marker = Marker(
    color = Color.RGB(158, 202, 225),
    opacity = 0.6,
    line = Line(
      color = Color.RGB(8, 48, 107),
      width = 1.5
    )
  )
)

val data = Seq(trace1)

val annotations = xValue.zip(yValue).map {
  case (x, y) =>
    Annotation(
      x = x,
      y = y,
      text = y.toString,
      xanchor = Anchor.Center,
      yanchor = Anchor.Bottom,
      showarrow = false
    )
}

val layout = Layout(
  title = "January 2013 Sales Report",
  annotations = annotations
)

plot(data, layout)
// Out:
// xValue: Seq[String] = List("Product A", "Product B", "Product C")
// yValue: Seq[Int] = List(20, 14, 23)
// trace1: Bar = Bar(
//   Strings(List("Product A", "Product B", "Product C")),
// ...
// data: Seq[Bar] = List(
//   Bar(
// ...
// annotations: Seq[Annotation] = List(
//   Annotation(
// ...
// layout: Layout = Layout(
//   Some("January 2013 Sales Report"),
// ...
// res6_6: String = "plot-826859132"

// %% [markdown]
// ## Customizing Individual Bar Colors

// %%
val defaultColor = Color.RGBA(204,204,204,1)
val highlightColor = Color.RGBA(222,45,38,0.8)

val trace1 = Bar(
  Seq("Feature A", "Feature B", "Feature C", "Feature D", "Feature E"),
  Seq(20, 14, 23, 25, 22),
  marker = Marker(
    color = Seq(
      defaultColor, highlightColor, defaultColor, defaultColor, defaultColor
    )
  )
)

val data = Seq(trace1)

val layout = Layout(
  title = "Least Used Feature"
)

plot(data, layout)
// Out:
// defaultColor: Color.RGBA = RGBA(204, 204, 204, 1.0)
// highlightColor: Color.RGBA = RGBA(222, 45, 38, 0.8)
// trace1: Bar = Bar(
//   Strings(List("Feature A", "Feature B", "Feature C", "Feature D", "Feature E"))...
// data: Seq[Bar] = List(
//   Bar(
// ...
// layout: Layout = Layout(
//   Some("Least Used Feature"),
// ...
// res7_5: String = "plot-925234040"

// %% [markdown]
// ## Waterfall Bar Chart

// %%
val xData = Seq(
  "Product Revenue",
  "Services Revenue",
  "Total Revenue",
  "Fixed Costs",
  "Variable Costs",
  "Total Costs",
  "Total"
)

val yData = Seq(400, 660, 660, 590, 400, 400, 340)

val textList = Seq("$430K", "$260K", "$690K", "$-120K", "$-200K", "$-320K", "$370K")

//Base

val trace1 = Bar(
  x = xData,
  y = Seq(0, 430, 0, 570, 370, 370, 0),
  marker = Marker(
    color = Color.RGBA(1, 1, 1, 0.0)
  )
)

//Revenue

val trace2 = Bar(
  xData,
  Seq(430, 260, 690, 0, 0, 0, 0),
  marker = Marker(
    color = Color.RGBA(55, 128, 191, 0.7),
    line = Line(
      color = Color.RGBA(55, 128, 191, 1.0),
      width = 2.0
    )
  )
)

//Cost

val trace3 = Bar(
  xData,
  Seq(0, 0, 0, 120, 200, 320, 0),
  marker = Marker(
    color = Color.RGBA(219, 64, 82, 0.7),
    line = Line(
      color = Color.RGBA(219, 64, 82, 1.0),
      width = 2.0
    )
  )
)

//Profit

val trace4 = Bar(
  xData,
  Seq(0, 0, 0, 0, 0, 0, 370),
  marker = Marker(
    color = Color.RGBA(50,171, 96, 0.7),
    line = Line(
      color = Color.RGBA(50, 171, 96, 1.0),
      width = 2.0
    )
  )
)

val data = Seq(trace1, trace2, trace3, trace4)

val annotations = xData.zip(yData).zip(textList).map {
  case ((x, y), text) =>
    Annotation(
      x = x,
      y = y,
      text = text,
      font = Font(
        family = "Arial",
        size = 14,
        color = Color.RGBA(245, 246, 249, 1)
      ),
      showarrow = false
    )
}

val layout = Layout(
  title = "Annual Profit 2015",
  barmode = BarMode.Stack,
  paper_bgcolor = Color.RGBA(245, 246, 249, 1),
  plot_bgcolor = Color.RGBA(245, 246, 249, 1),
  width = 600,
  height = 400,
  showlegend = false,
  annotations = annotations
)

plot(data, layout)
// Out:
// xData: Seq[String] = List(
//   "Product Revenue",
// ...
// yData: Seq[Int] = List(400, 660, 660, 590, 400, 400, 340)
// textList: Seq[String] = List(
//   "$430K",
// ...
// trace1: Bar = Bar(
//   Strings(
// ...
// trace2: Bar = Bar(
//   Strings(
// ...
// trace3: Bar = Bar(
//   Strings(
// ...
// trace4: Bar = Bar(
//   Strings(
// ...
// data: Seq[Bar] = List(
//   Bar(
// ...
// annotations: Seq[Annotation] = List(
//   Annotation(
// ...
// layout: Layout = Layout(
//   Some("Annual Profit 2015"),
// ...
// res8_10: String = "plot-1690974949"

// %% [markdown]
// # Horizontal Bar Charts
// ## Basic Horizontal Bar Chart

// %%
val data = Seq(Bar(
  Seq(20, 14, 23),
  Seq("giraffes", "orangutans", "monkeys"),
  orientation = Orientation.Horizontal
))

plot(data)
// Out:
// data: Seq[Bar] = List(
//   Bar(
// ...
// res9_1: String = "plot-536844942"

// %% [markdown]
// ## Colored Bar Chart

// %%
val trace1 = Bar(
  Seq(20, 14, 23),
  Seq("giraffes", "orangutans", "monkeys"),
  name = "SF Zoo",
  orientation = Orientation.Horizontal,
  marker = Marker(
    color = Color.RGBA(55, 128, 191, 0.6),
    width = 1
  )
)

val trace2 = Bar(
  Seq(12, 18, 29),
  Seq("giraffes", "orangutans", "monkeys"),
  name = "LA Zoo",
  orientation = Orientation.Horizontal,
  marker = Marker(
    color = Color.RGBA(255, 153, 51, 0.6),
    width = 1
  )
)

val data = Seq(trace1, trace2)

val layout = Layout(
  title = "Colored Bar Chart",
  barmode = BarMode.Stack
)

plot(data, layout)
// Out:
// trace1: Bar = Bar(
//   Doubles(List(20.0, 14.0, 23.0)),
// ...
// trace2: Bar = Bar(
//   Doubles(List(12.0, 18.0, 29.0)),
// ...
// data: Seq[Bar] = List(
//   Bar(
// ...
// layout: Layout = Layout(
//   Some("Colored Bar Chart"),
// ...
// res10_4: String = "plot-383669333"

// %% [markdown]
// # Time Series
// ## Time Series Chart

// %%
val data = Seq(
  Scatter(
    Seq("2013-10-04 22:23:00", "2013-11-04 22:23:00", "2013-12-04 22:23:00"),
    Seq(1, 3, 6)
  )
)

plot(data)
// Out:
// data: Seq[Scatter] = List(
//   Scatter(
// ...
// res11_1: String = "plot-1384559300"

// %% [markdown]
// # Bubble Charts
// ## Hover on Text Bubble Chart

// %%
val trace1 = Scatter(
  Seq(1, 2, 3, 4),
  Seq(10, 11, 12, 13),
  text = Seq("""A
  size = 40""", """B
  size = 60""", """C
  size = 80""", """D
  size = 100"""),
  mode = ScatterMode(ScatterMode.Markers),
  marker = Marker(
    color = Seq(Color.RGB(93, 164, 214), Color.RGB(255, 144, 14), Color.RGB(44, 160, 101), Color.RGB(255, 65, 54)),
    size = Seq(40, 60, 80, 100)
  )
)

val data = Seq(trace1)

val layout = Layout(
  title = "Bubble Chart Hover Text",
  showlegend = false,
  height = 400,
  width = 600
)

plot(data, layout)
// Out:
// trace1: Scatter = Scatter(
//   Some(Doubles(List(1.0, 2.0, 3.0, 4.0))),
// ...
// data: Seq[Scatter] = List(
//   Scatter(
// ...
// layout: Layout = Layout(
//   Some("Bubble Chart Hover Text"),
// ...
// res12_3: String = "plot-58512271"

// %% [markdown]
// # Filled Area Plots
// ## Basic Overlaid Area Chart

// %%
val trace1 = Scatter(
  Seq(1, 2, 3, 4),
  Seq(0, 2, 3, 5),
  fill = Fill.ToZeroY
)

val trace2 = Scatter(
  Seq(1, 2, 3, 4),
  Seq(3, 5, 1, 7),
  fill = Fill.ToNextY
)

val data = Seq(trace1, trace2)

plot(data)
// Out:
// trace1: Scatter = Scatter(
//   Some(Doubles(List(1.0, 2.0, 3.0, 4.0))),
// ...
// trace2: Scatter = Scatter(
//   Some(Doubles(List(1.0, 2.0, 3.0, 4.0))),
// ...
// data: Seq[Scatter] = List(
//   Scatter(
// ...
// res13_3: String = "plot-1652906988"
