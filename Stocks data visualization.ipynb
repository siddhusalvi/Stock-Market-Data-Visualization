// %%
import $ivy.`org.apache.spark::spark-sql:2.4.3`
// Out:
// import $ivy.$

// %%
import org.apache.log4j.{Level, Logger}
Logger.getLogger("org").setLevel(Level.OFF)
// Out:
// import org.apache.log4j.{Level, Logger}

// %%
import org.apache.spark.sql._
// Out:
// import org.apache.spark.sql._

// %%
val spark = {
  SparkSession.builder()
    .master("local[*]")
    .getOrCreate()
}
// Out:
// Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
// spark: SparkSession = org.apache.spark.sql.SparkSession@7b6afbf7

// %%
def sc = spark.sparkContext
// Out:
// defined function sc

// %%
import $ivy.`org.vegas-viz:vegas_2.11:0.3.11`
import $ivy.`org.vegas-viz:vegas-spark_2.11:0.3.11`
// Out:
// import $ivy.$
//
// import $ivy.$

// %%
import vegas._
import vegas.render.WindowRenderer._
import vegas.sparkExt._
import vegas.data.External._
// Out:
// import vegas._
//
// import vegas.render.WindowRenderer._
//
// import vegas.sparkExt._
//
// import vegas.data.External._

// %%
Vegas("Stock prices of 5 Tech Companies Over Time.", width = 500.0, height =300.0)
    .withURL(Stocks, formatType = DataFormat.Csv)
    .mark(Line)
    .encodeX("date", Temp)
    .encodeY("price", Quant)
    .encodeDetailFields(Field(field="symbol", dataType=Nominal))
    .show
// Out:
//   <iframe id="frame-vegas-ad2236df-2a06-458d-9489-bb37c944f813" sandbox="allow-scripts allow-same-origin" style="border: none; width: 100%" srcdoc="&lt;html&gt;
//   &lt;head&gt;
//     &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/d3/3.5.17/d3.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega/2.6.3/vega.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega-lite/1.2.0/vega-lite.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://vega.github.io/vega-editor/vendor/vega-embed.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
//   &lt;/head&gt;
//   &lt;body&gt;
//  &lt;div id='vegas-ad2236df-2a06-458d-9489-bb37c944f813'&gt;&lt;/div&gt;
//  &lt;script&gt;
//    var embedSpec = {
//      mode: &quot;vega-lite&quot;,
//      spec: {
// ...

// %%
Vegas("Sample Multi Series Line Chart", width = 500.0, height =300.0)
      .withURL(Stocks, formatType = DataFormat.Csv)
      .mark(Line)
      .encodeX("date", Temp)
      .encodeY("price", Quant)
      .encodeColor(field = "symbol", dataType = Nominal, legend = Legend(orient = "left", title = "Stock Symbol"))
      .show
// Out:
//   <iframe id="frame-vegas-753234a8-31f7-4acf-ae6b-d1d1945b47eb" sandbox="allow-scripts allow-same-origin" style="border: none; width: 100%" srcdoc="&lt;html&gt;
//   &lt;head&gt;
//     &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/d3/3.5.17/d3.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega/2.6.3/vega.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://cdn.jsdelivr.net/webjars/org.webjars.bower/vega-lite/1.2.0/vega-lite.min.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
// &lt;script src=&quot;https://vega.github.io/vega-editor/vendor/vega-embed.js&quot; charset=&quot;utf-8&quot;&gt;&lt;/script&gt;
//   &lt;/head&gt;
//   &lt;body&gt;
//  &lt;div id='vegas-753234a8-31f7-4acf-ae6b-d1d1945b47eb'&gt;&lt;/div&gt;
//  &lt;script&gt;
//    var embedSpec = {
//      mode: &quot;vega-lite&quot;,
//      spec: {
// ...
